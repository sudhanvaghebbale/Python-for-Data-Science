# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# To get a histogram, it gets a call to the matplotlib

df1['A'].hist()

# %%
df1['A'].plot(kind = 'hist')

# %%
df1['A'].plot.hist()

# %% [markdown]
# # Area Plot

# %%
df2.plot.area(alpha = 0.4)

# %%
df2.plot.bar() # Index should be categorical

# %%
df2.plot.bar(stacked = True)

# %%
df2.plot.hist()

# %%
df1['B'].plot.line()

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'magma')  # s = Marker Size and c = Color

# %%
df1.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns = ['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -0.088799 -0.753546
# 1 -0.304074  0.330844
# 2 -0.632411 -0.290288
# 3 -0.879554  0.827777
# 4  0.576882  0.640637

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize = 25, cmap = 'magma')

# %%
df.plot.kde()

# %%
df.plot.density()
